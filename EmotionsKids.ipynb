# %% [markdown]
# <a href="https://colab.research.google.com/github/EmoDetect/emodetect/blob/main/EmotionsKids.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow
### CNN models ###
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D, SeparableConv2D
from keras.utils import np_utils
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, RMSprop
from tensorflow.keras.utils import to_categorical
from keras.layers.normalization.batch_normalization import BatchNormalization
from tensorflow.keras import models
from keras.utils.vis_utils import plot_model
from tensorflow.keras.layers import Input, GlobalAveragePooling2D,concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras.applications.inception_v3 import InceptionV3


from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, roc_auc_score

# %% [markdown]
# Parameters

# %%
batch_size = 32
num_epochs = 50
input_shape = (48, 48, 1)
validation_split = .2
verbose = 1
num_classes = 7
base_path = 'models/'
shape_x = 48
shape_y = 48
image_size=(48,48)
labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# %% [markdown]
# Data

# %%
data=pd.read_csv('/content/sample_data/fer2013/fer2013.csv')
print(len(data))
# Out:
# 17497

# %%
data['pixels']=data['pixels'].astype("string")
pixels = data['pixels'].tolist()
width, height = 48, 48
faces = []
for pixel_sequence in pixels:
    face = [int(pixel) for pixel in pixel_sequence.strip().split(' ',48*48)]
    if len(face) == 2304:
      face = np.asarray(face).reshape(width, height)
      face = cv2.resize(face.astype('uint8'),image_size)
      faces.append(face.astype('float32'))
last = faces[-1]
faces.append(last)
faces = np.asarray(faces)
faces = np.expand_dims(faces, -1)
faces /= 127.5
faces -= 1.
emotions = pd.get_dummies(data['emotion']).to_numpy()

# %%
print(len(faces))
# Out:
# 17497

# %%
datagen = ImageDataGenerator(
        zoom_range=0.2,          # randomly zoom into images
        rotation_range=10,       # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,   # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,    # randomly flip images
        vertical_flip=False)     # randomly flip images

# %%
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.3,shuffle=True)
xval,xtest,yval,ytest=train_test_split(xtest,ytest,test_size=0.3,shuffle=True)

# %% [markdown]
# CNN

# %%
def CNN():
    model = Sequential(name='CNN')
    model.add(Conv2D(64, (3, 3), padding='same', input_shape=(48,48,1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
    model.add(Dropout(0.25))

    model.add(Conv2D(256, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
    model.add(Dropout(0.25))

    model.add(Conv2D(512, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(512))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(Dense(256))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(Dense(7))
    model.add(Activation('softmax'))
    
    return model

# %%
CNN=CNN()

# %% [markdown]
# Training

# %%
early_stop = EarlyStopping('val_loss', patience=100)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1,
                                  patience=25, min_lr=0.00001,model='auto')
trained_models_path = base_path + 'CNN'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,
                                                    save_best_only=True)
callbacks = [model_checkpoint, early_stop, reduce_lr]

# %%
CNN.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
CNN_history =CNN.fit(datagen.flow(xtrain, ytrain, batch_size),
          steps_per_epoch=len(xtrain) / batch_size, 
          epochs=num_epochs, 
          verbose=1, 
          callbacks=callbacks,
          validation_data=(xval,yval))
# Out:
# Epoch 1/50
# 383/382 [==============================] - ETA: 0s - loss: 1.9234 - accuracy: 0.2402
# Epoch 00001: val_loss improved from inf to 1.91916, saving model to models/CNN.01-0.18.hdf5
# 382/382 [==============================] - 293s 761ms/step - loss: 1.9234 - accuracy: 0.2402 - val_loss: 1.9192 - val_accuracy: 0.1829 - lr: 0.0010
# Epoch 2/50
# 383/382 [==============================] - ETA: 0s - loss: 1.7472 - accuracy: 0.3113
# Epoch 00002: val_loss improved from 1.91916 to 1.62731, saving model to models/CNN.02-0.37.hdf5
# 382/382 [==============================] - 286s 746ms/step - loss: 1.7472 - accuracy: 0.3113 - val_loss: 1.6273 - val_accuracy: 0.3676 - lr: 0.0010
# Epoch 3/50
# 383/382 [==============================] - ETA: 0s - loss: 1.6211 - accuracy: 0.3623
# Epoch 00003: val_loss improved from 1.62731 to 1.50404, saving model to models/CNN.03-0.43.hdf5
# 382/382 [==============================] - 288s 753ms/step - loss: 1.6211 - accuracy: 0.3623 - val_loss: 1.5040 - val_accuracy: 0.4259 - lr: 0.0010
# Epoch 4/50
# 383/382 [==============================] - ETA: 0s - loss: 1.5257 - accuracy: 0.4051
# Epoch 00004: val_loss did not improve from 1.50404
# 382/382 [==============================] - 288s 752ms/step - loss: 1.5257 - accuracy: 0.4051 - val_loss: 1.6575 - val_accuracy: 0.3788 - lr: 0.0010
# Epoch 5/50
# 383/382 [==============================] - ETA: 0s - loss: 1.4532 - accuracy: 0.4381
# Epoch 00005: val_loss improved from 1.50404 to 1.31532, saving model to models/CNN.05-0.49.hdf5
# 382/382 [==============================] - 288s 752ms/step - loss: 1.4532 - accuracy: 0.4381 - val_loss: 1.3153 - val_accuracy: 0.4912 - lr: 0.0010
# Epoch 6/50
# 383/382 [==============================] - ETA: 0s - loss: 1.4051 - accuracy: 0.4576
# Epoch 00006: val_loss improved from 1.31532 to 1.30278, saving model to models/CNN.06-0.49.hdf5
# 382/382 [==============================] - 288s 753ms/step - loss: 1.4051 - accuracy: 0.4576 - val_loss: 1.3028 - val_accuracy: 0.4887 - lr: 0.0010
# Epoch 7/50
# 383/382 [==============================] - ETA: 0s - loss: 1.3686 - accuracy: 0.4752
# Epoch 00007: val_loss improved from 1.30278 to 1.29561, saving model to models/CNN.07-0.51.hdf5
# 382/382 [==============================] - 287s 751ms/step - loss: 1.3686 - accuracy: 0.4752 - val_loss: 1.2956 - val_accuracy: 0.5094 - lr: 0.0010
# Epoch 8/50
# 383/382 [==============================] - ETA: 0s - loss: 1.3418 - accuracy: 0.4874
# Epoch 00008: val_loss improved from 1.29561 to 1.28518, saving model to models/CNN.08-0.51.hdf5
# 382/382 [==============================] - 287s 751ms/step - loss: 1.3418 - accuracy: 0.4874 - val_loss: 1.2852 - val_accuracy: 0.5121 - lr: 0.0010
# Epoch 9/50
# 383/382 [==============================] - ETA: 0s - loss: 1.3256 - accuracy: 0.4937
# Epoch 00009: val_loss improved from 1.28518 to 1.21368, saving model to models/CNN.09-0.53.hdf5
# 382/382 [==============================] - 287s 751ms/step - loss: 1.3256 - accuracy: 0.4937 - val_loss: 1.2137 - val_accuracy: 0.5322 - lr: 0.0010
# Epoch 10/50
# 383/382 [==============================] - ETA: 0s - loss: 1.3037 - accuracy: 0.5031
# Epoch 00010: val_loss did not improve from 1.21368
# 382/382 [==============================] - 287s 749ms/step - loss: 1.3037 - accuracy: 0.5031 - val_loss: 1.2300 - val_accuracy: 0.5260 - lr: 0.0010
# Epoch 11/50
# 383/382 [==============================] - ETA: 0s - loss: 1.2778 - accuracy: 0.5117
# Epoch 00011: val_loss improved from 1.21368 to 1.21246, saving model to models/CNN.11-0.53.hdf5
# 382/382 [==============================] - 288s 754ms/step - loss: 1.2778 - accuracy: 0.5117 - val_loss: 1.2125 - val_accuracy: 0.5325 - lr: 0.0010
# Epoch 12/50
# 383/382 [==============================] - ETA: 0s - loss: 1.2719 - accuracy: 0.5139
# Epoch 00012: val_loss did not improve from 1.21246
# 382/382 [==============================] - 287s 751ms/step - loss: 1.2719 - accuracy: 0.5139 - val_loss: 1.2642 - val_accuracy: 0.5091 - lr: 0.0010
# Epoch 13/50
# 383/382 [==============================] - ETA: 0s - loss: 1.2547 - accuracy: 0.5197
# Epoch 00013: val_loss improved from 1.21246 to 1.20555, saving model to models/CNN.13-0.54.hdf5
# 382/382 [==============================] - 287s 749ms/step - loss: 1.2547 - accuracy: 0.5197 - val_loss: 1.2056 - val_accuracy: 0.5377 - lr: 0.0010
# Epoch 14/50
# 383/382 [==============================] - ETA: 0s - loss: 1.2351 - accuracy: 0.5308
# Epoch 00014: val_loss improved from 1.20555 to 1.16082, saving model to models/CNN.14-0.56.hdf5
# 382/382 [==============================] - 287s 750ms/step - loss: 1.2351 - accuracy: 0.5308 - val_loss: 1.1608 - val_accuracy: 0.5619 - lr: 0.0010
# Epoch 15/50
# 383/382 [==============================] - ETA: 0s - loss: 1.2155 - accuracy: 0.5368
# Epoch 00015: val_loss did not improve from 1.16082
# 382/382 [==============================] - 287s 750ms/step - loss: 1.2155 - accuracy: 0.5368 - val_loss: 1.1706 - val_accuracy: 0.5548 - lr: 0.0010
# Epoch 16/50
# 383/382 [==============================] - ETA: 0s - loss: 1.2124 - accuracy: 0.5353
# Epoch 00016: val_loss did not improve from 1.16082
# 382/382 [==============================] - 286s 747ms/step - loss: 1.2124 - accuracy: 0.5353 - val_loss: 1.1733 - val_accuracy: 0.5567 - lr: 0.0010
# Epoch 17/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1958 - accuracy: 0.5441
# Epoch 00017: val_loss improved from 1.16082 to 1.15503, saving model to models/CNN.17-0.56.hdf5
# 382/382 [==============================] - 287s 750ms/step - loss: 1.1958 - accuracy: 0.5441 - val_loss: 1.1550 - val_accuracy: 0.5646 - lr: 0.0010
# Epoch 18/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1747 - accuracy: 0.5491
# Epoch 00018: val_loss improved from 1.15503 to 1.10563, saving model to models/CNN.18-0.58.hdf5
# 382/382 [==============================] - 287s 749ms/step - loss: 1.1747 - accuracy: 0.5491 - val_loss: 1.1056 - val_accuracy: 0.5823 - lr: 0.0010
# Epoch 19/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1745 - accuracy: 0.5512
# Epoch 00019: val_loss did not improve from 1.10563
# 382/382 [==============================] - 287s 750ms/step - loss: 1.1745 - accuracy: 0.5512 - val_loss: 1.1815 - val_accuracy: 0.5562 - lr: 0.0010
# Epoch 20/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1715 - accuracy: 0.5560
# Epoch 00020: val_loss did not improve from 1.10563
# 382/382 [==============================] - 288s 751ms/step - loss: 1.1715 - accuracy: 0.5560 - val_loss: 1.1417 - val_accuracy: 0.5736 - lr: 0.0010
# Epoch 21/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1538 - accuracy: 0.5602
# Epoch 00021: val_loss did not improve from 1.10563
# 382/382 [==============================] - 288s 752ms/step - loss: 1.1538 - accuracy: 0.5602 - val_loss: 1.1520 - val_accuracy: 0.5527 - lr: 0.0010
# Epoch 22/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1398 - accuracy: 0.5644
# Epoch 00022: val_loss did not improve from 1.10563
# 382/382 [==============================] - 289s 756ms/step - loss: 1.1398 - accuracy: 0.5644 - val_loss: 1.1456 - val_accuracy: 0.5717 - lr: 0.0010
# Epoch 23/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1329 - accuracy: 0.5683
# Epoch 00023: val_loss did not improve from 1.10563
# 382/382 [==============================] - 290s 759ms/step - loss: 1.1329 - accuracy: 0.5683 - val_loss: 1.1059 - val_accuracy: 0.5842 - lr: 0.0010
# Epoch 24/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1291 - accuracy: 0.5733
# Epoch 00024: val_loss improved from 1.10563 to 1.10082, saving model to models/CNN.24-0.59.hdf5
# 382/382 [==============================] - 294s 767ms/step - loss: 1.1291 - accuracy: 0.5733 - val_loss: 1.1008 - val_accuracy: 0.5850 - lr: 0.0010
# Epoch 25/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1143 - accuracy: 0.5730
# Epoch 00025: val_loss did not improve from 1.10082
# 382/382 [==============================] - 288s 752ms/step - loss: 1.1143 - accuracy: 0.5730 - val_loss: 1.1050 - val_accuracy: 0.5907 - lr: 0.0010
# Epoch 26/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1057 - accuracy: 0.5773
# Epoch 00026: val_loss improved from 1.10082 to 1.08686, saving model to models/CNN.26-0.59.hdf5
# 382/382 [==============================] - 287s 750ms/step - loss: 1.1057 - accuracy: 0.5773 - val_loss: 1.0869 - val_accuracy: 0.5946 - lr: 0.0010
# Epoch 27/50
# 383/382 [==============================] - ETA: 0s - loss: 1.1028 - accuracy: 0.5806
# Epoch 00027: val_loss improved from 1.08686 to 1.07961, saving model to models/CNN.27-0.60.hdf5
# 382/382 [==============================] - 286s 746ms/step - loss: 1.1028 - accuracy: 0.5806 - val_loss: 1.0796 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 28/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0949 - accuracy: 0.5823
# Epoch 00028: val_loss improved from 1.07961 to 1.07401, saving model to models/CNN.28-0.60.hdf5
# 382/382 [==============================] - 285s 746ms/step - loss: 1.0949 - accuracy: 0.5823 - val_loss: 1.0740 - val_accuracy: 0.5981 - lr: 0.0010
# Epoch 29/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0839 - accuracy: 0.5888
# Epoch 00029: val_loss improved from 1.07401 to 1.04808, saving model to models/CNN.29-0.61.hdf5
# 382/382 [==============================] - 286s 746ms/step - loss: 1.0839 - accuracy: 0.5888 - val_loss: 1.0481 - val_accuracy: 0.6082 - lr: 0.0010
# Epoch 30/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0709 - accuracy: 0.5983
# Epoch 00030: val_loss did not improve from 1.04808
# 382/382 [==============================] - 286s 746ms/step - loss: 1.0709 - accuracy: 0.5983 - val_loss: 1.0802 - val_accuracy: 0.5981 - lr: 0.0010
# Epoch 31/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0649 - accuracy: 0.6001
# Epoch 00031: val_loss did not improve from 1.04808
# 382/382 [==============================] - 286s 747ms/step - loss: 1.0649 - accuracy: 0.6001 - val_loss: 1.0850 - val_accuracy: 0.5902 - lr: 0.0010
# Epoch 32/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0584 - accuracy: 0.5975
# Epoch 00032: val_loss did not improve from 1.04808
# 382/382 [==============================] - 286s 747ms/step - loss: 1.0584 - accuracy: 0.5975 - val_loss: 1.0913 - val_accuracy: 0.5940 - lr: 0.0010
# Epoch 33/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0425 - accuracy: 0.6043
# Epoch 00033: val_loss improved from 1.04808 to 1.03713, saving model to models/CNN.33-0.62.hdf5
# 382/382 [==============================] - 286s 749ms/step - loss: 1.0425 - accuracy: 0.6043 - val_loss: 1.0371 - val_accuracy: 0.6169 - lr: 0.0010
# Epoch 34/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0485 - accuracy: 0.6014
# Epoch 00034: val_loss did not improve from 1.03713
# 382/382 [==============================] - 286s 746ms/step - loss: 1.0485 - accuracy: 0.6014 - val_loss: 1.0476 - val_accuracy: 0.6169 - lr: 0.0010
# Epoch 35/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0310 - accuracy: 0.6070
# Epoch 00035: val_loss did not improve from 1.03713
# 382/382 [==============================] - 286s 746ms/step - loss: 1.0310 - accuracy: 0.6070 - val_loss: 1.1420 - val_accuracy: 0.5801 - lr: 0.0010
# Epoch 36/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0181 - accuracy: 0.6104
# Epoch 00036: val_loss did not improve from 1.03713
# 382/382 [==============================] - 285s 746ms/step - loss: 1.0181 - accuracy: 0.6104 - val_loss: 1.0589 - val_accuracy: 0.6090 - lr: 0.0010
# Epoch 37/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0238 - accuracy: 0.6128
# Epoch 00037: val_loss did not improve from 1.03713
# 382/382 [==============================] - 285s 745ms/step - loss: 1.0238 - accuracy: 0.6128 - val_loss: 1.0519 - val_accuracy: 0.6038 - lr: 0.0010
# Epoch 38/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0196 - accuracy: 0.6124
# Epoch 00038: val_loss did not improve from 1.03713
# 382/382 [==============================] - 285s 746ms/step - loss: 1.0196 - accuracy: 0.6124 - val_loss: 1.0867 - val_accuracy: 0.6003 - lr: 0.0010
# Epoch 39/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0099 - accuracy: 0.6157
# Epoch 00039: val_loss did not improve from 1.03713
# 382/382 [==============================] - 285s 745ms/step - loss: 1.0099 - accuracy: 0.6157 - val_loss: 1.0864 - val_accuracy: 0.5932 - lr: 0.0010
# Epoch 40/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9971 - accuracy: 0.6228
# Epoch 00040: val_loss improved from 1.03713 to 1.02004, saving model to models/CNN.40-0.63.hdf5
# 382/382 [==============================] - 287s 749ms/step - loss: 0.9971 - accuracy: 0.6228 - val_loss: 1.0200 - val_accuracy: 0.6261 - lr: 0.0010
# Epoch 41/50
# 383/382 [==============================] - ETA: 0s - loss: 1.0029 - accuracy: 0.6213
# Epoch 00041: val_loss did not improve from 1.02004
# 382/382 [==============================] - 286s 747ms/step - loss: 1.0029 - accuracy: 0.6213 - val_loss: 1.0769 - val_accuracy: 0.6049 - lr: 0.0010
# Epoch 42/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9837 - accuracy: 0.6288
# Epoch 00042: val_loss did not improve from 1.02004
# 382/382 [==============================] - 287s 750ms/step - loss: 0.9837 - accuracy: 0.6288 - val_loss: 1.0965 - val_accuracy: 0.6093 - lr: 0.0010
# Epoch 43/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9882 - accuracy: 0.6237
# Epoch 00043: val_loss did not improve from 1.02004
# 382/382 [==============================] - 288s 753ms/step - loss: 0.9882 - accuracy: 0.6237 - val_loss: 1.0478 - val_accuracy: 0.6218 - lr: 0.0010
# Epoch 44/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9827 - accuracy: 0.6282
# Epoch 00044: val_loss did not improve from 1.02004
# 382/382 [==============================] - 288s 753ms/step - loss: 0.9827 - accuracy: 0.6282 - val_loss: 1.0730 - val_accuracy: 0.6109 - lr: 0.0010
# Epoch 45/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9723 - accuracy: 0.6309
# Epoch 00045: val_loss did not improve from 1.02004
# 382/382 [==============================] - 288s 753ms/step - loss: 0.9723 - accuracy: 0.6309 - val_loss: 1.0544 - val_accuracy: 0.6101 - lr: 0.0010
# Epoch 46/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9564 - accuracy: 0.6391
# Epoch 00046: val_loss did not improve from 1.02004
# 382/382 [==============================] - 288s 753ms/step - loss: 0.9564 - accuracy: 0.6391 - val_loss: 1.0655 - val_accuracy: 0.6141 - lr: 0.0010
# Epoch 47/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9654 - accuracy: 0.6330
# Epoch 00047: val_loss did not improve from 1.02004
# 382/382 [==============================] - 288s 752ms/step - loss: 0.9654 - accuracy: 0.6330 - val_loss: 1.0761 - val_accuracy: 0.6147 - lr: 0.0010
# Epoch 48/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9597 - accuracy: 0.6376
# Epoch 00048: val_loss did not improve from 1.02004
# 382/382 [==============================] - 288s 752ms/step - loss: 0.9597 - accuracy: 0.6376 - val_loss: 1.0433 - val_accuracy: 0.6199 - lr: 0.0010
# Epoch 49/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9439 - accuracy: 0.6419
# Epoch 00049: val_loss did not improve from 1.02004
# 382/382 [==============================] - 288s 752ms/step - loss: 0.9439 - accuracy: 0.6419 - val_loss: 1.0486 - val_accuracy: 0.6210 - lr: 0.0010
# Epoch 50/50
# 383/382 [==============================] - ETA: 0s - loss: 0.9548 - accuracy: 0.6411
# Epoch 00050: val_loss did not improve from 1.02004
# 382/382 [==============================] - 287s 749ms/step - loss: 0.9548 - accuracy: 0.6411 - val_loss: 1.0672 - val_accuracy: 0.6180 - lr: 0.0010

# %%
fig,axes=plt.subplots(2,2,figsize=(20, 20))
for (m,history), ax in zip({'CNN':CNN_history}.items(),axes):
    # Loss Curves
    
    ax[0].plot(history.history['loss'],'r',linewidth=2.0)
    ax[0].plot(history.history['val_loss'],'b',linewidth=2.0)
    ax[0].legend(['Training loss', 'Validation Loss'],fontsize=18)
    ax[0].set_xlabel('Epochs ',fontsize=16)
    ax[0].set_ylabel('Loss',fontsize=16)
    ax[0].set_title('Loss Curves '+m,fontsize=16)
 
    # Accuracy Curves
    ax[1].plot(history.history['accuracy'],'r',linewidth=2.0)
    ax[1].plot(history.history['val_accuracy'],'b',linewidth=2.0)
    ax[1].legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
    ax[1].set_xlabel('Epochs ',fontsize=16)
    ax[1].set_ylabel('Accuracy',fontsize=16)
    ax[1].set_title('Accuracy Curves '+m,fontsize=16)

# %%
  ypred=CNN.predict(xtest)
  ypred_=np.argmax(ypred, axis=1)
  ytest_=np.argmax(ytest, axis=1)
  print(classification_report(ytest_, ypred_,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.485     0.507     0.496       223
#            1      0.500     0.385     0.435        26
#            2      0.524     0.304     0.385       247
#            3      0.835     0.852     0.844       393
#            4      0.532     0.504     0.518       264
#            5      0.691     0.675     0.683       166
#            6      0.505     0.723     0.595       256
#
#     accuracy                          0.611      1575
#    macro avg      0.582     0.564     0.565      1575
# weighted avg      0.612     0.611     0.604      1575

# %%
import itertools
from sklearn.metrics import confusion_matrix
from matplotlib.pyplot import figure


fig = figure(figsize=(10, 10))
    
ypred=CNN.predict(xtest)
rounded_predections=np.argmax(ypred, axis=1)
rounded_labels=np.argmax(ytest, axis=1)
cm = confusion_matrix(rounded_labels, rounded_predections)
title='Confusion matrix '+CNN.name
    

plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title(title)
plt.colorbar()
tick_marks = np.arange(len(labels))
plt.xticks(tick_marks, labels, rotation=45)
plt.yticks(tick_marks, labels)
fmt = 'd'
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")
    
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.show()
